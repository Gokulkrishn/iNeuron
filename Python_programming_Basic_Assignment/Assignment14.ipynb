# %% [markdown]
# Question 1:
# Define a class with a generator which can iterate the numbers, which are divisible by
# 7, between a given range 0 and n.
#
#     In [57]: class Div7:
#         ...:     def __init__(self,n,d):
#         ...:         self.n = n
#         ...:         self.d = d
#         ...:     def __iter__(self):
#         ...:         self.i = 0
#         ...:         return self
#         ...:     def __next__(self):
#         ...:         if self.i+self.d-1 >= self.n:
#         ...:             raise StopIteration
#         ...:         while True:
#         ...:             self.i +=1
#         ...:             if self.i%self.d==0:
#         ...:                 return self.i
#         ...:
#
#     In [58]: d7 = iter(Div7(120,7))
#
#     In [59]: for i in d7:
#         ...:     print(i)

# %% [markdown]
# Question 2:
# Write a program to compute the frequency of the words from the input. The output
# should output after sorting the key alphanumerically.
# Suppose the following input is supplied to the program:
# New to Python or choosing between Python 2 and Python 3? Read Python 2 or
# Python 3.
# Then, the output should be:
# 2:2
# 3.:1
# 3?:1
# New:1
# Python:5
# Read:1
# and:1
# between:1
# choosing:1
# or:2
# to:1
#
#         In [89]: text = input("enter the string ")
#         enter the string New to Python or choosing between Python 2 and Python 3? Read Python 2 or Python 3
#
#         In [90]: word_count = {}
#             ...: for word in text.split(' '):
#             ...:     if word in word_count.keys():
#             ...:         word_count[word] += 1
#             ...:     else:
#             ...:         word_count[word] = 1
#             ...:
#
#         In [91]: for k,v in sorted(word_count.items()):
#             ...:     print(k,end=':')
#             ...:     print(v)

# %% [markdown]
# Question 3:
#
# Define a class Person and its two child classes: Male and Female. All classes have a
# method &quot;getGender&quot; which can print &quot;Male&quot; for Male class and &quot;Female&quot; for Female
# class.
#
#     In [118]: class  Person:
#          ...:     def  getGender(self):
#          ...:         return  "Unknown"
#          ...: class  Male(Person):
#          ...:     def  getGender(self):
#          ...:         return  "Male"
#          ...: class  Female(Person):
#          ...:     def  getGender(self):
#          ...:         return  "Female"
#          ...:

# %% [markdown]
# Question 4:
# Please write a program to generate all sentences where subject is in [&quot;I&quot;, &quot;You&quot;] and
# verb is in [&quot;Play&quot;, &quot;Love&quot;] and the object is in [&quot;Hockey&quot;,&quot;Football&quot;].
#
#         In [151]: for each in [[i,j,k] for k in object for j in verb for i in subject]:
#              ...:     print(' '.join(each))
#              ...:
#         I Play Hockey
#         You Play Hockey
#         I Love Hockey
#         You Love Hockey
#         I Play Football
#         You Play Football
#         I Love Football
#         You Love Football

# %% [markdown]
# Question 5:
# Please write a program to compress and decompress the string &quot;hello world!hello
# world!hello world!hello world!&quot;.
#
#         In [121]: import zlib
#
#         In [122]: s = 'hello world!hello world!hello world!hello world!'.encode()
#
#         In [123]: t = zlib.compress(s)
#
#         In [124]: t
#         Out[124]: b'x\x9c\xcbH\xcd\xc9\xc9W(\xcf/\xcaIQ\xcc \x82\r\x00\xbd[\x11\xf5'
#
#         In [125]: zlib.decompress(t)

# %% [markdown]
# Question 6:
# Please write a binary search function which searches an item in a sorted list. The
# function should return the index of element to be searched in the list.
#
#
#         In [90]: def bin(l,i,s,e):
#             ...:     if s > e:
#             ...:         return -1
#             ...:     mi = (s+e)//2
#             ...:     if l[mi] == i:
#             ...:         return mi
#             ...:     else:
#             ...:         if l[mi]<i:
#             ...:             s =mi+1
#             ...:         elif l[mi] >i:
#             ...:             e = mi-1
#             ...:     return bin(l,i,s,e)
